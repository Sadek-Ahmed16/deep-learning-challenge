# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns=['EIN', 'NAME'])

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_type_counts = application_df['APPLICATION_TYPE'].value_counts()
application_type_counts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = application_type_counts[application_type_counts < 700].index.tolist()

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# Other      804
# T8         737
# T7         725
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_counts = application_df['CLASSIFICATION'].value_counts()
classification_counts
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_counts_gt_1 = classification_counts[classification_counts > 1]
classification_counts_gt_1
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = classification_counts[classification_counts < 1900].index.tolist()

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     4144
# C3000     1918
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_encoded = pd.get_dummies(application_df)

# %%
# Split our preprocessed data into our features and target arrays
y = application_encoded["IS_SUCCESSFUL"].values
X = application_encoded.drop(["IS_SUCCESSFUL"],1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)
# Out:
# <ipython-input-10-4c3de42f8771>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X = application_encoded.drop(["IS_SUCCESSFUL"],1).values

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
X.shape
# Out:
# (34299, 41)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0]) # 41
hidden_nodes_layer1 =  27
hidden_nodes_layer2 = 18
hidden_nodes_layer3 = 12

nn3 = tf.keras.models.Sequential()

# First hidden layer
nn3.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn3.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Third hidden layer
nn3.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="relu"))

# Output layer
nn3.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn3.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 27)                1134
#
#  dense_1 (Dense)             (None, 18)                504
#
#  dense_2 (Dense)             (None, 12)                228
#
#  dense_3 (Dense)             (None, 1)                 13
#
# =================================================================
# Total params: 1879 (7.34 KB)
# Trainable params: 1879 (7.34 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn3.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn3.fit(X_train_scaled,y_train,epochs=150)
# Out:
# Epoch 1/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5836 - accuracy: 0.7115
# Epoch 2/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5594 - accuracy: 0.7267
# Epoch 3/150
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5569 - accuracy: 0.7293
# Epoch 4/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5551 - accuracy: 0.7301
# Epoch 5/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5543 - accuracy: 0.7304
# Epoch 6/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5534 - accuracy: 0.7315
# Epoch 7/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5528 - accuracy: 0.7322
# Epoch 8/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5523 - accuracy: 0.7312
# Epoch 9/150
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5515 - accuracy: 0.7311
# Epoch 10/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5509 - accuracy: 0.7323
# Epoch 11/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5512 - accuracy: 0.7323
# Epoch 12/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5499 - accuracy: 0.7328
# Epoch 13/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5496 - accuracy: 0.7336
# Epoch 14/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5499 - accuracy: 0.7334
# Epoch 15/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5495 - accuracy: 0.7328
# Epoch 16/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5489 - accuracy: 0.7338
# Epoch 17/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5487 - accuracy: 0.7336
# Epoch 18/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5490 - accuracy: 0.7344
# Epoch 19/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5487 - accuracy: 0.7334
# Epoch 20/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5480 - accuracy: 0.7332
# Epoch 21/150
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5489 - accuracy: 0.7338
# Epoch 22/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5473 - accuracy: 0.7345
# Epoch 23/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5482 - accuracy: 0.7348
# Epoch 24/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5478 - accuracy: 0.7352
# Epoch 25/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5479 - accuracy: 0.7338
# Epoch 26/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5476 - accuracy: 0.7345
# Epoch 27/150
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5474 - accuracy: 0.7345
# Epoch 28/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5469 - accuracy: 0.7357
# Epoch 29/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5469 - accuracy: 0.7352
# Epoch 30/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5466 - accuracy: 0.7353
# Epoch 31/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5471 - accuracy: 0.7351
# Epoch 32/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5466 - accuracy: 0.7349
# Epoch 33/150
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5463 - accuracy: 0.7355
# Epoch 34/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5463 - accuracy: 0.7358
# Epoch 35/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5467 - accuracy: 0.7344
# Epoch 36/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5462 - accuracy: 0.7360
# Epoch 37/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5457 - accuracy: 0.7357
# Epoch 38/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5461 - accuracy: 0.7363
# Epoch 39/150
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5458 - accuracy: 0.7354
# Epoch 40/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5465 - accuracy: 0.7349
# Epoch 41/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5457 - accuracy: 0.7360
# Epoch 42/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5456 - accuracy: 0.7356
# Epoch 43/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5457 - accuracy: 0.7354
# Epoch 44/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5449 - accuracy: 0.7357
# Epoch 45/150
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5459 - accuracy: 0.7363
# Epoch 46/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5454 - accuracy: 0.7356
# Epoch 47/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5453 - accuracy: 0.7365
# Epoch 48/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5452 - accuracy: 0.7357
# Epoch 49/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5452 - accuracy: 0.7353
# Epoch 50/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5453 - accuracy: 0.7366
# Epoch 51/150
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5450 - accuracy: 0.7359
# Epoch 52/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5449 - accuracy: 0.7359
# Epoch 53/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5448 - accuracy: 0.7355
# Epoch 54/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5446 - accuracy: 0.7369
# Epoch 55/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5444 - accuracy: 0.7366
# Epoch 56/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5443 - accuracy: 0.7370
# Epoch 57/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5443 - accuracy: 0.7364
# Epoch 58/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5445 - accuracy: 0.7366
# Epoch 59/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5443 - accuracy: 0.7361
# Epoch 60/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5443 - accuracy: 0.7367
# Epoch 61/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5442 - accuracy: 0.7371
# Epoch 62/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5436 - accuracy: 0.7361
# Epoch 63/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5441 - accuracy: 0.7364
# Epoch 64/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5437 - accuracy: 0.7372
# Epoch 65/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5440 - accuracy: 0.7365
# Epoch 66/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5438 - accuracy: 0.7371
# Epoch 67/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5438 - accuracy: 0.7372
# Epoch 68/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5437 - accuracy: 0.7375
# Epoch 69/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5437 - accuracy: 0.7368
# Epoch 70/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5439 - accuracy: 0.7366
# Epoch 71/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5437 - accuracy: 0.7365
# Epoch 72/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5429 - accuracy: 0.7373
# Epoch 73/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5433 - accuracy: 0.7376
# Epoch 74/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5432 - accuracy: 0.7366
# Epoch 75/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5431 - accuracy: 0.7371
# Epoch 76/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5436 - accuracy: 0.7365
# Epoch 77/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5433 - accuracy: 0.7373
# Epoch 78/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5435 - accuracy: 0.7367
# Epoch 79/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5435 - accuracy: 0.7363
# Epoch 80/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5429 - accuracy: 0.7374
# Epoch 81/150
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5427 - accuracy: 0.7373
# Epoch 82/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5435 - accuracy: 0.7370
# Epoch 83/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5431 - accuracy: 0.7369
# Epoch 84/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5428 - accuracy: 0.7372
# Epoch 85/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5426 - accuracy: 0.7377
# Epoch 86/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5427 - accuracy: 0.7378
# Epoch 87/150
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5427 - accuracy: 0.7377
# Epoch 88/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5430 - accuracy: 0.7379
# Epoch 89/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5428 - accuracy: 0.7378
# Epoch 90/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5427 - accuracy: 0.7366
# Epoch 91/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5424 - accuracy: 0.7377
# Epoch 92/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5425 - accuracy: 0.7377
# Epoch 93/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5430 - accuracy: 0.7372
# Epoch 94/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5426 - accuracy: 0.7371
# Epoch 95/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5422 - accuracy: 0.7376
# Epoch 96/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5426 - accuracy: 0.7376
# Epoch 97/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5423 - accuracy: 0.7379
# Epoch 98/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5421 - accuracy: 0.7381
# Epoch 99/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5419 - accuracy: 0.7379
# Epoch 100/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5420 - accuracy: 0.7377
# Epoch 101/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5423 - accuracy: 0.7378
# Epoch 102/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5422 - accuracy: 0.7372
# Epoch 103/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5415 - accuracy: 0.7381
# Epoch 104/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5421 - accuracy: 0.7368
# Epoch 105/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5421 - accuracy: 0.7376
# Epoch 106/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5420 - accuracy: 0.7371
# Epoch 107/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5416 - accuracy: 0.7385
# Epoch 108/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5424 - accuracy: 0.7377
# Epoch 109/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5414 - accuracy: 0.7377
# Epoch 110/150
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5422 - accuracy: 0.7385
# Epoch 111/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5418 - accuracy: 0.7383
# Epoch 112/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5421 - accuracy: 0.7379
# Epoch 113/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5412 - accuracy: 0.7389
# Epoch 114/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5413 - accuracy: 0.7381
# Epoch 115/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5412 - accuracy: 0.7386
# Epoch 116/150
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5414 - accuracy: 0.7376
# Epoch 117/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5419 - accuracy: 0.7383
# Epoch 118/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5417 - accuracy: 0.7383
# Epoch 119/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5415 - accuracy: 0.7384
# Epoch 120/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5415 - accuracy: 0.7375
# Epoch 121/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5415 - accuracy: 0.7381
# Epoch 122/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5414 - accuracy: 0.7383
# Epoch 123/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5415 - accuracy: 0.7385
# Epoch 124/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5412 - accuracy: 0.7383
# Epoch 125/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5414 - accuracy: 0.7376
# Epoch 126/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5409 - accuracy: 0.7384
# Epoch 127/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5415 - accuracy: 0.7374
# Epoch 128/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5412 - accuracy: 0.7380
# Epoch 129/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5415 - accuracy: 0.7381
# Epoch 130/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5412 - accuracy: 0.7384
# Epoch 131/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5412 - accuracy: 0.7383
# Epoch 132/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5413 - accuracy: 0.7378
# Epoch 133/150
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5411 - accuracy: 0.7377
# Epoch 134/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5411 - accuracy: 0.7387
# Epoch 135/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5413 - accuracy: 0.7386
# Epoch 136/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5406 - accuracy: 0.7382
# Epoch 137/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5407 - accuracy: 0.7392
# Epoch 138/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5411 - accuracy: 0.7381
# Epoch 139/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5405 - accuracy: 0.7374
# Epoch 140/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5409 - accuracy: 0.7378
# Epoch 141/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5406 - accuracy: 0.7375
# Epoch 142/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5410 - accuracy: 0.7381
# Epoch 143/150
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5408 - accuracy: 0.7386
# Epoch 144/150
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5409 - accuracy: 0.7376
# Epoch 145/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5405 - accuracy: 0.7381
# Epoch 146/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5403 - accuracy: 0.7383
# Epoch 147/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5406 - accuracy: 0.7384
# Epoch 148/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5406 - accuracy: 0.7381
# Epoch 149/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5404 - accuracy: 0.7384
# Epoch 150/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5408 - accuracy: 0.7381

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn3.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5607 - accuracy: 0.7261 - 1s/epoch - 4ms/step
# Loss: 0.5607113242149353, Accuracy: 0.726064145565033

# %%
# Export our model to HDF5 file
nn3.save("AlphabetSoupCharity_Optimization2.h5")
